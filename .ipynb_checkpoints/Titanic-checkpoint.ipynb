# %% [markdown]
# # Titanic

# %% [markdown]
# **Author: Wade Evans**
# Reference: https://www.kaggle.com/c/titanic/

# %% [markdown]
# **The Challenge**
# The sinking of the Titanic is one of the most infamous shipwrecks in history.
#
# On April 15, 1912, during her maiden voyage, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg. Unfortunately, there weren’t enough lifeboats for everyone onboard, resulting in the death of 1502 out of 2224 passengers and crew.
#
# While there was some element of luck involved in surviving, it seems some groups of people were more likely to survive than others.
#
# In this challenge, we ask you to build a predictive model that answers the question: “what sorts of people were more likely to survive?” using passenger data (ie name, age, gender, socio-economic class, etc).

# %% [markdown]
# **Data**
# train.csv will contain the details of a subset of the passengers on board (891 to be exact) and importantly, will reveal whether they survived or not, also known as the “ground truth”.
#
# The `test.csv` dataset contains similar information but does not disclose the “ground truth” for each passenger. It’s your job to predict these outcomes.
#
# Using the patterns you find in the train.csv data, predict whether the other 418 passengers on board (found in test.csv) survived.

# %% [markdown]
# **Data dictionary**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Variable Notes**
#
# **pclass**: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# **age**: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# **sibsp1**: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# **parch**: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data

# %%
train_df = pd.read_csv('train.csv')

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Missing data

# %% [markdown]
# **From the above info, it looks like there is missing data!**

# %%
train_df.isnull().values.any()
# Out:
# True

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **19.87% of the 'Age' data is missing. Possibly 'impute' missing data.
# ---> Impute: Assign a value to something by inference.
# 77.10% of the 'Cabin' data is missing. This is too much missing data. Possibly drop this column.
# 0.22% of the 'Embarked' data is missing. Possibly drop the 2 rows of missing data.**

# %% [markdown]
# ## EDA

# %%
# Survivors:
    # 0 = did not survive
    # 1 = did survive

train_df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(data=train_df,x='Survived')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
train_df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# **Only 54.42% of the passengers were female.**

# %%
sns.countplot(data=train_df,x='Sex')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(data=train_df,x='Survived',hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
# To get number of females who did not survive

train_df[(train_df['Sex']=='female') & (train_df['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# To get number of females who did not survive

train_df[(train_df['Sex']=='female') & (train_df['Survived']==0)]['Sex'].count()
# Out:
# 81

# %%
# To get number of females who did survive

train_df[(train_df['Sex']=='female') & (train_df['Survived']==1)]['Sex'].count()
# Out:
# 233

# %%
# To get number of males who did not survive

train_df[(train_df['Sex']=='male') & (train_df['Survived']==0)]['Sex'].count()
# Out:
# 468

# %%
# To get number of males who did survive

train_df[(train_df['Sex']=='male') & (train_df['Survived']==1)]['Sex'].count()
# Out:
# 109

# %% [markdown]
# **81 out of 314 (25.80%) females did not survive.
# 468 out of 577 (81.11%) males did not survive.**

# %%
by_survived = train_df.groupby('Survived')

# %%
by_survived.mean()
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
sns.countplot(data=train_df,x='Pclass')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(data=train_df,x='Survived',hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# **More people with a Pclass of 1 survived than people with a Pclass of 3, even though there were significantly less people with a Pclass of 1 onboard.**

# %%
sns.displot(data=train_df,x='Fare',hue='Survived',height=10)

# %%
sns.displot(data=train_df,x='Age',hue='Survived')

# %% [markdown]
# **Looks like young children are more likely to survive**

# %%
sns.displot(data=train_df,x='SibSp',hue='Survived')

# %%
sns.displot(data=train_df,x='Parch',hue='Survived',alpha=0.5)

# %% [markdown]
# **From the above, you are more likely to survive if:
# ---> you have a lower Pclass
# ---> you paid a higher Fare (on average)
# ---> you are female
# ---> you are a young child**

# %% [markdown]
# ## Dealing with the missing data

# %% [markdown]
# Previously, we saw that the 'Age', 'Cabin', and 'Embarked' columns have missing data.

# %%
sns.boxplot(data=train_df,x='Pclass',y='Age')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
round(train_df[train_df['Pclass']==1]['Age'].mean())
# Out:
# 38

# %%
round(train_df[train_df['Pclass']==2]['Age'].mean())
# Out:
# 30

# %%
round(train_df[train_df['Pclass']==3]['Age'].mean())
# Out:
# 25

# %% [markdown]
# **The higher the class, the higher the mean age.
# Use the mean age values to impute based on Pclass for Age.**

# %%
train_df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
train_df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
train_df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
pd.isnull(train_df['Age'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]
    
    if pd.isnull(Age):
        
        if Pclass == 1:
            return 38
        
        elif Pclass == 2:
            return 30
        
        else:
            return 25
        
    else:
        return Age

# %%
train_df['Age'] = train_df[['Age','Pclass']].apply(impute_age,axis=1)

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Remove the 'Cabin' column

train_df.drop('Cabin',axis=1,inplace=True)

# %%
train_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
# Remove rows with missing values (should remove the remaining 2 rows with missing values)

train_df.dropna(inplace=True)

# %%
train_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Converting categorical features

# %% [markdown]
# Convert categorical features to dummy variables.

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
train_df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
sex = pd.get_dummies(train_df['Sex'],drop_first=True)

# %%
sex.head()
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
embark = pd.get_dummies(train_df['Embarked'],drop_first=True)

# %%
embark.head()
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
pclass = pd.get_dummies(train_df['Pclass'],drop_first=True)

# %%
pclass.head()
# Out:
#    2  3
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  0
# 4  0  1

# %%
train_df.drop(['Sex','Embarked','Pclass','Name','Ticket','PassengerId'],axis=1,inplace=True)

# %%
train_df.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare
# 0         0  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         1  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         0  35.0      0      0   8.0500

# %%
train_df = pd.concat([train_df,sex,embark,pclass],axis=1)

# %%
train_df
# Out:
#      Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0           0  22.0      1      0   7.2500     1  0  1  0  1
# 1           1  38.0      1      0  71.2833     0  0  0  0  0
# 2           1  26.0      0      0   7.9250     0  0  1  0  1
# 3           1  35.0      1      0  53.1000     0  0  1  0  0
# 4           0  35.0      0      0   8.0500     1  0  1  0  1
# ..        ...   ...    ...    ...      ...   ... .. .. .. ..
# 886         0  27.0      0      0  13.0000     1  0  1  1  0
# 887         1  19.0      0      0  30.0000     0  0  1  0  0
# 888         0  25.0      1      2  23.4500     0  0  1  0  1
# 889         1  26.0      0      0  30.0000     1  0  0  0  0
# 890         0  32.0      0      0   7.7500     1  1  0  0  1
#
# [889 rows x 10 columns]

# %% [markdown]
# ## Model prediction - Logistic regression

# %% [markdown]
# ### Train Test Split

# %%
X = train_df.drop('Survived',axis=1)
y = train_df['Survived']

# %%
X.head()
# Out:
#     Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0  22.0      1      0   7.2500     1  0  1  0  1
# 1  38.0      1      0  71.2833     0  0  0  0  0
# 2  26.0      0      0   7.9250     0  0  1  0  1
# 3  35.0      1      0  53.1000     0  0  1  0  0
# 4  35.0      0      0   8.0500     1  0  1  0  1

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Creating the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ### Predictions on test set

# %%
log_pred = logmodel.predict(X_test)

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,log_pred))
print('\n')
print(classification_report(y_test,log_pred))
# Out:
# [[146  21]
#  [ 28  72]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86       167
#            1       0.77      0.72      0.75       100
#
#     accuracy                           0.82       267
#    macro avg       0.81      0.80      0.80       267
# weighted avg       0.81      0.82      0.82       267

# %% [markdown]
# ### Try normalising the data before creating the model

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train
# Out:
#       Age  SibSp  Parch     Fare  male  Q  S  2  3
# 486  35.0      1      0  90.0000     0  0  1  0  0
# 293  24.0      0      0   8.8500     0  0  1  0  1
# 173  21.0      0      0   7.9250     1  0  1  0  1
# 450  36.0      1      2  27.7500     1  0  1  1  0
# 361  29.0      1      0  27.7208     1  0  0  1  0
# ..    ...    ...    ...      ...   ... .. .. .. ..
# 107  25.0      0      0   7.7750     1  0  1  0  1
# 271  25.0      0      0   0.0000     1  0  1  0  1
# 862  48.0      0      0  25.9292     0  0  1  0  0
# 436  21.0      2      2  34.3750     0  0  1  0  1
# 103  33.0      0      0   8.6542     1  0  1  0  1
#
# [622 rows x 9 columns]

# %%
X_train.iloc[:,3]
# Out:
# 486    90.0000
# 293     8.8500
# 173     7.9250
# 450    27.7500
# 361    27.7208
#         ...
# 107     7.7750
# 271     0.0000
# 862    25.9292
# 436    34.3750
# 103     8.6542
# Name: Fare, Length: 622, dtype: float64

# %%
X_train.iloc[:,0]
# Out:
# 486    35.0
# 293    24.0
# 173    21.0
# 450    36.0
# 361    29.0
#        ...
# 107    25.0
# 271    25.0
# 862    48.0
# 436    21.0
# 103    33.0
# Name: Age, Length: 622, dtype: float64

# %%
X_test
# Out:
#       Age  SibSp  Parch      Fare  male  Q  S  2  3
# 281  28.0      0      0    7.8542     1  0  1  0  1
# 435  14.0      1      2  120.0000     0  0  1  0  0
# 39   14.0      1      0   11.2417     0  0  0  0  1
# 418  30.0      0      0   13.0000     1  0  1  1  0
# 585  18.0      0      2   79.6500     0  0  1  0  0
# ..    ...    ...    ...       ...   ... .. .. .. ..
# 454  25.0      0      0    8.0500     1  0  1  0  1
# 632  32.0      0      0   30.5000     1  0  0  0  0
# 693  25.0      0      0    7.2250     1  0  0  0  1
# 741  36.0      1      0   78.8500     1  0  1  0  0
# 430  28.0      0      0   26.5500     1  0  1  0  0
#
# [267 rows x 9 columns]

# %% [markdown]
# **Maybe only the 'Age' and 'Fare' columns should be normalised?**

# %%
X_train[['Age','Fare']]
# Out:
#       Age     Fare
# 486  35.0  90.0000
# 293  24.0   8.8500
# 173  21.0   7.9250
# 450  36.0  27.7500
# 361  29.0  27.7208
# ..    ...      ...
# 107  25.0   7.7750
# 271  25.0   0.0000
# 862  48.0  25.9292
# 436  21.0  34.3750
# 103  33.0   8.6542
#
# [622 rows x 2 columns]

# %%
X_train[['Age','Fare']] = scaler.fit_transform(X_train[['Age','Fare']])
# Out:
# <ipython-input-72-230ac6d8be15>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[['Age','Fare']] = scaler.fit_transform(X_train[['Age','Fare']])
# C:\Users\user-pc\anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
X_test[['Age','Fare']] = scaler.transform(X_test[['Age','Fare']])
# Out:
# <ipython-input-73-748fb7deac15>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[['Age','Fare']] = scaler.transform(X_test[['Age','Fare']])
# C:\Users\user-pc\anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
X_train
# Out:
#           Age  SibSp  Parch      Fare  male  Q  S  2  3
# 486  0.434531      1      0  0.175668     0  0  1  0  0
# 293  0.296306      0      0  0.017274     0  0  1  0  1
# 173  0.258608      0      0  0.015469     1  0  1  0  1
# 450  0.447097      1      2  0.054164     1  0  1  1  0
# 361  0.359135      1      0  0.054107     1  0  0  1  0
# ..        ...    ...    ...       ...   ... .. .. .. ..
# 107  0.308872      0      0  0.015176     1  0  1  0  1
# 271  0.308872      0      0  0.000000     1  0  1  0  1
# 862  0.597889      0      0  0.050610     0  0  1  0  0
# 436  0.258608      2      2  0.067096     0  0  1  0  1
# 103  0.409399      0      0  0.016892     1  0  1  0  1
#
# [622 rows x 9 columns]

# %%
X_test
# Out:
#           Age  SibSp  Parch      Fare  male  Q  S  2  3
# 281  0.346569      0      0  0.015330     1  0  1  0  1
# 435  0.170646      1      2  0.234224     0  0  1  0  0
# 39   0.170646      1      0  0.021942     0  0  0  0  1
# 418  0.371701      0      0  0.025374     1  0  1  1  0
# 585  0.220910      0      2  0.155466     0  0  1  0  0
# ..        ...    ...    ...       ...   ... .. .. .. ..
# 454  0.308872      0      0  0.015713     1  0  1  0  1
# 632  0.396833      0      0  0.059532     1  0  0  0  0
# 693  0.308872      0      0  0.014102     1  0  0  0  1
# 741  0.447097      1      0  0.153905     1  0  1  0  0
# 430  0.346569      0      0  0.051822     1  0  1  0  0
#
# [267 rows x 9 columns]

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
log_pred = logmodel.predict(X_test)
print(confusion_matrix(y_test,log_pred))
print('\n')
print(classification_report(y_test,log_pred))
# Out:
# [[140  27]
#  [ 28  72]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.84       167
#            1       0.73      0.72      0.72       100
#
#     accuracy                           0.79       267
#    macro avg       0.78      0.78      0.78       267
# weighted avg       0.79      0.79      0.79       267

# %% [markdown]
# ### Remove normalising and try different C values

# %% [markdown]
# ### C=0.1 (default = 1)

# %% [markdown]
# **Smaller values of C represent stronger regularisation**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
logmodel = LogisticRegression(C=0.1)
logmodel.fit(X_train,y_train)
log_pred = logmodel.predict(X_test)
print(confusion_matrix(y_test,log_pred))
print('\n')
print(classification_report(y_test,log_pred))
# Out:
# [[150  17]
#  [ 32  68]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       167
#            1       0.80      0.68      0.74       100
#
#     accuracy                           0.82       267
#    macro avg       0.81      0.79      0.80       267
# weighted avg       0.82      0.82      0.81       267
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### C=5 (default = 1)

# %%
logmodel = LogisticRegression(C=5)
logmodel.fit(X_train,y_train)
log_pred = logmodel.predict(X_test)
print(confusion_matrix(y_test,log_pred))
print('\n')
print(classification_report(y_test,log_pred))
# Out:
# [[142  25]
#  [ 27  73]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85       167
#            1       0.74      0.73      0.74       100
#
#     accuracy                           0.81       267
#    macro avg       0.79      0.79      0.79       267
# weighted avg       0.80      0.81      0.80       267
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### C=10 (default = 1)

# %%
logmodel = LogisticRegression(C=10)
logmodel.fit(X_train,y_train)
log_pred = logmodel.predict(X_test)
print(confusion_matrix(y_test,log_pred))
print('\n')
print(classification_report(y_test,log_pred))
# Out:
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [[140  27]
#  [ 27  73]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       167
#            1       0.73      0.73      0.73       100
#
#     accuracy                           0.80       267
#    macro avg       0.78      0.78      0.78       267
# weighted avg       0.80      0.80      0.80       267

# %% [markdown]
# ## Model prediciton - KNN

# %%
X_test
# Out:
#       Age  SibSp  Parch      Fare  male  Q  S  2  3
# 281  28.0      0      0    7.8542     1  0  1  0  1
# 435  14.0      1      2  120.0000     0  0  1  0  0
# 39   14.0      1      0   11.2417     0  0  0  0  1
# 418  30.0      0      0   13.0000     1  0  1  1  0
# 585  18.0      0      2   79.6500     0  0  1  0  0
# ..    ...    ...    ...       ...   ... .. .. .. ..
# 454  25.0      0      0    8.0500     1  0  1  0  1
# 632  32.0      0      0   30.5000     1  0  0  0  0
# 693  25.0      0      0    7.2250     1  0  0  0  1
# 741  36.0      1      0   78.8500     1  0  1  0  0
# 430  28.0      0      0   26.5500     1  0  1  0  0
#
# [267 rows x 9 columns]

# %%
X_train
# Out:
#       Age  SibSp  Parch     Fare  male  Q  S  2  3
# 486  35.0      1      0  90.0000     0  0  1  0  0
# 293  24.0      0      0   8.8500     0  0  1  0  1
# 173  21.0      0      0   7.9250     1  0  1  0  1
# 450  36.0      1      2  27.7500     1  0  1  1  0
# 361  29.0      1      0  27.7208     1  0  0  1  0
# ..    ...    ...    ...      ...   ... .. .. .. ..
# 107  25.0      0      0   7.7750     1  0  1  0  1
# 271  25.0      0      0   0.0000     1  0  1  0  1
# 862  48.0      0      0  25.9292     0  0  1  0  0
# 436  21.0      2      2  34.3750     0  0  1  0  1
# 103  33.0      0      0   8.6542     1  0  1  0  1
#
# [622 rows x 9 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
knn_predictions = knn.predict(X_test)

# %%
print(confusion_matrix(y_test,knn_predictions))
print('\n')
print(classification_report(y_test,knn_predictions))
# Out:
# [[130  37]
#  [ 53  47]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74       167
#            1       0.56      0.47      0.51       100
#
#     accuracy                           0.66       267
#    macro avg       0.63      0.62      0.63       267
# weighted avg       0.65      0.66      0.66       267

# %% [markdown]
# ### Choosing a K value

# %%
error_rate = []

for i in range(1,41):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    knn_predictions = knn.predict(X_test)
    error_rate.append(np.mean(knn_predictions != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,41),error_rate,color='blue',linestyle='dashed',marker='o', markerfacecolor='red',markersize=10)
plt.title('Error Rate vs K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# ### K=15

# %%
knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train,y_train)
knn_predictions = knn.predict(X_test)
print(confusion_matrix(y_test,knn_predictions))
print('\n')
print(classification_report(y_test,knn_predictions))
# Out:
# [[145  22]
#  [ 50  50]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80       167
#            1       0.69      0.50      0.58       100
#
#     accuracy                           0.73       267
#    macro avg       0.72      0.68      0.69       267
# weighted avg       0.73      0.73      0.72       267
